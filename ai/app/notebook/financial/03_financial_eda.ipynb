# %% [markdown]
# # Financial Dataset EDA
#
# This notebook explores the PaySim financial transaction dataset.

# %%
from pathlib import Path
import pandas as pd

DATA_PATH = Path('../../../datasets/paysim.csv')
df = pd.read_csv(DATA_PATH)
df.head()

# %%
df.info()
df.describe(include='all').T
